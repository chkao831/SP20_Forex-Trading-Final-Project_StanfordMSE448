# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('..')

import pandas as pd
import os
import mplfinance as mpf

import utils

# %%
pd.set_option('display.max_rows', 99999)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
api = utils.DataAPI()

# %%
df_usdcad = api.get('EURUSD', '1', start_time='2019-02-04 00:00', length=None, end_time='2019-02-04 23:59')
# Out:
# 200456
# 200456

# %%
df_usdcad

# %%
usdcad_lp1_candles = utils.generate_candles(df_usdcad, '30s', 'bid price')
mpf.plot(usdcad_lp1_candles, mav=(3,6,15), type='candle', volume=True,show_nontrading=True, figratio=(15,10),figscale=1.5)

# %%
df_eurusd = api.get('EURUSD', '1', '2019-02-01 01:00', 600*1000)

# %%
eurusd_lp1_candles = utils.generate_candles(df2, '10m', 'bid price')
mpf.plot(eurusd_lp1_candles, mav=(3,6,15), type='candle', volume=True,show_nontrading=True, figratio=(15,10),figscale=1.5)
